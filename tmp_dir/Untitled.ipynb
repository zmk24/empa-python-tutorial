# %%
import mypackage
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mypackage
#
# ModuleNotFoundError: No module named 'mypackage'

# %%
import numpy

# %%
import mypackage

# %%
p1=mypackage.Point(0,1)

# %%
mypackage.__file__
# Out:
# '/srv/conda/envs/notebook/lib/python3.10/site-packages/mypackage/__init__.py'
